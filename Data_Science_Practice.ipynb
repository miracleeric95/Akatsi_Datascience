# %%
with open("my_text.txt", "w") as f:
 f.write("I love to code in Python")

# %%
with open("my_text.txt", "r") as f:
    text_1 = f.readlines()
    print(text_1)
# Out:
# ['I love to code in Python']

# %%
data_dick= { 'books ' :12,  'articles': 100, 'subjects': ['maths' , 'programming' , 'data science'] }
import json
j_String= json.dumps(data_dick)
print(j_String)
# Out:
# {"books ": 12, "articles": 100, "subjects": ["maths", "programming", "data science"]}

# %%
dick_convert=json.loads(j_String)
print(dick_convert)
# Out:
# {'books ': 12, 'articles': 100, 'subjects': ['maths', 'programming', 'data science']}

# %%
import pandas as pd
customer_id = pd.read_csv('Customers.csv')
customer_id.head()
# Out:
#    Index      Customer Id First Name Last Name                      Company  \
# 0      1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1      2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2      3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3      4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4      5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
#
#                City           Country                Phone 1  \
# 0       Rowlandberg             Macao      846-790-4623x4715
# 1          Bethside  Papua New Guinea     124-597-8652x05682
# 2      Moniquemouth             China     (335)987-3085x3780
# 3        Leeborough             Macao          (047)752-3122
# 4  Port Jacksonland             Nepal  +1-360-693-4419x19272
#
#                Phone 2                          Email Subscription Date  \
# ...

# %%
import pandas as pd
df= pd.read_excel('gad.xlsx')
df.head()
# Out:
#    SN                        NAME ELECTORAL AREA        POLLING STATION  \
# 0   1      TAGBODZA, JAMES DELASE      VE- DEME      TRAD.COUN. VE-DEME
# 1   2  TAGBODZA, SAMPSON WOELINAM      VE- DEME    E.P. PRIM. SCH. DEME
# 2   3               WALTER DOKPUI      VE- DEME       L.A. JHS GBORDOME
# 3   4                TENE, EUNICE      VE- DEME   E.P. PRIM. SCH. HOEME
# 4   5             DOKPUIE, GODWIN      VE- DEME       L.A. JHS GBORDOME
#
#           POSITION    CONTACT
# 0         CHAIRMAN  593144000
# 1  YOUTH ORGANISER  599654276
# 2      COORDINATOR  241838021
# 3        SECRETARY  532526326
# 4  YOUTH ORGANISER  241028428

# %%
import numpy as np
a= np.array(32)
print(a)
# Out:
# 32

# %%
b=np.array([10,20,30,40,50])
b.ndim
# Out:
# 1

# %%
c= np.zeros((2,4))

print(c)
# Out:
# [[0. 0. 0. 0.]
#  [0. 0. 0. 0.]]
